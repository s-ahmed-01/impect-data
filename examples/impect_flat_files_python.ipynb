# %%
import pandas as pd
from functions.load_data import load_matches, load_match_events, load_match_scorings

# %%
# load matches from open data repository
matches = load_matches()

# show matches
matches.head()
# Out:
#    iterationId      id  matchDayIndex matchDayName  homeSquadId  \
# 0          743  122838              0  1. Spieltag           38
# 1          743  122839              0  1. Spieltag           41
# 2          743  122840              0  1. Spieltag           30
# 3          743  122841              0  1. Spieltag           31
# 4          743  122842              0  1. Spieltag           46
#
#          homeSquadName  awaySquadId           awaySquadName  \
# 0     SV Werder Bremen           33       FC Bayern München
# 1  Bayer 04 Leverkusen           37  RasenBallsport Leipzig
# 2        VfL Wolfsburg          432   1. FC Heidenheim 1846
# 3  TSG 1899 Hoffenheim           34             SC Freiburg
# 4        VfB Stuttgart          416              VfL Bochum
#
#           scheduledDate          lastCalculationDate  available
# 0  2023-08-18T18:30:00Z  2025-08-28T06:30:00.471380Z       True
# 1  2023-08-19T13:30:00Z  2025-07-24T01:26:33.441698Z       True
# ...

# %%
# extract list of match ids
match_ids = matches["id"].tolist()
match_ids = [122839, 122840, 122841]

# load event data
events = load_match_events(match_ids=match_ids)

# show events
events.head()
# Out:
#             matchId              dateTime  iterationId  matchDayIndex  \
# eventId
# 4614749499   122839  2023-08-19T13:30:00Z          743              0
# 4614749500   122839  2023-08-19T13:30:00Z          743              0
# 4614749501   122839  2023-08-19T13:30:00Z          743              0
# 4614749502   122839  2023-08-19T13:30:00Z          743              0
# 4614749503   122839  2023-08-19T13:30:00Z          743              0
#
#            matchDayName  homeSquadId        homeSquadName  awaySquadId  \
# eventId
# 4614749499  1. Spieltag           41  Bayer 04 Leverkusen           37
# 4614749500  1. Spieltag           41  Bayer 04 Leverkusen           37
# 4614749501  1. Spieltag           41  Bayer 04 Leverkusen           37
# 4614749502  1. Spieltag           41  Bayer 04 Leverkusen           37
# 4614749503  1. Spieltag           41  Bayer 04 Leverkusen           37
#
#                      awaySquadName  eventNumber  ...  shotTargetPointY  \
# ...

# %%
# load event scorings
scorings = load_match_scorings(match_ids=match_ids)

# show events
scorings.head()
# Out:
#    matchId     eventId  playerId        position  kpiId           kpiName  \
# 0   122839  4614749499      2735  CENTER_FORWARD   1406      PXT_SETPIECE
# 1   122839  4614749499      2735  CENTER_FORWARD   1411      PXT_NO_VIDEO
# 2   122839  4614749499      2735  CENTER_FORWARD   1415  OPP_PXT_SETPIECE
# 3   122839  4614749499      2735  CENTER_FORWARD   1420  OPP_PXT_NO_VIDEO
# 4   122839  4614749499     66772  CENTER_FORWARD   1524  DEF_PXT_SETPIECE
#
#       value
# 0 -0.002559
# 1  0.005388
# 2  0.000178
# 3  0.000400
# 4 -0.002559
